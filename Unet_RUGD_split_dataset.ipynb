# %%
import segmentation_models as sm
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# Out:
# Segmentation Models: using `keras` framework.

# %%
# Define the color map
color_map = {
    0: [0, 0, 0],                # void
    1: [108, 64, 20],            # dirt
    2: [255, 229, 204],          # sand
    3: [0, 102, 0],              # grass
    4: [0, 255, 0],              # tree
    5: [0, 153, 153],            # pole
    6: [0, 128, 255],            # water
    7: [0, 0, 255],              # sky
    8: [255, 255, 0],            # vehicle
    9: [255, 0, 127],            # container/generic-object
    10: [64, 64, 64],            # asphalt
    11: [255, 128, 0],           # gravel
    12: [255, 0, 0],             # building
    13: [153, 76, 0],            # mulch
    14: [102, 102, 0],           # rock-bed
    15: [102, 0, 0],             # log
    16: [0, 255, 128],           # bicycle
    17: [204, 153, 255],         # person
    18: [102, 0, 204],           # fence
    19: [255, 153, 204],         # bush
    20: [0, 102, 102],           # sign
    21: [153, 204, 255],         # rock
    22: [102, 255, 255],         # bridge
    23: [101, 101, 11],          # concrete
    24: [114, 85, 47]            # picnic-table
}

# Create a reverse lookup to map colors to class labels
color_to_class = {tuple(value): key for key, value in color_map.items()}

def color_to_class_label(mask):
    # Convert mask to a 2D array where each pixel value is represented by an RGB tuple
    mask_rgb = mask.reshape(-1, 3)  # Reshape to a 2D array where each row is an RGB pixel

    # Map RGB values to class labels
    label_mask = np.array([color_to_class.get(tuple(rgb), 0) for rgb in mask_rgb])

    # Reshape back to the original mask shape (height, width)
    label_mask = label_mask.reshape(mask.shape[0], mask.shape[1])

    return label_mask

# def color_to_class_label(mask):
#     # Create an empty label mask
#     label_mask = np.zeros((mask.shape[0], mask.shape[1]), dtype=np.int32)  # Use np.int32 instead of np.long
    
#     # For each pixel, get the RGB value and map it to the class label
#     for i in range(mask.shape[0]):
#         for j in range(mask.shape[1]):
#             rgb_value = tuple(mask[i, j])
#             if rgb_value in color_to_class:
#                 label_mask[i, j] = color_to_class[rgb_value]
#             else:
#                 label_mask[i, j] = 0  # Default to class 0 if color is not found

#     return label_mask

# %%
# Paths
IMG_DIR = "./content/RUGD_frames"
MASK_DIR = "./content/RUGD_annotations"

IMG_SIZE = (672, 544)
NUM_CLASSES = 25  # Cityscapes has 19 semantic classes
BATCH_SIZE = 2  # Reduce batch size if kernel still crashes


# 🔹 **Get List of Files & Split Data**
def get_data_splits(test_size=0.1, val_size=0.1):
    img_files = []
    
    for root, _, files in os.walk(IMG_DIR):
        for file in files:
            if file.endswith('.png'):
                img_files.append(os.path.join(root, file))

    img_files.sort()  # Ensure consistency
    np.random.shuffle(img_files)  # Shuffle dataset

    # Split into train, validation, and test
    train_files, test_files = train_test_split(img_files, test_size=test_size, random_state=42)
    train_files, val_files = train_test_split(train_files, test_size=val_size / (1 - test_size), random_state=42)

    return train_files, val_files, test_files

# 🔹 **Function to Load Single Image**
def load_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, IMG_SIZE)
    img = img / 255.0  # Normalize
    return img

# 🔹 **Function to Load Single Mask**
def load_mask(mask_path):
    mask = cv2.imread(mask_path)  # Read as grayscale
    mask_resized = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    label_mask = color_to_class_label(mask_resized)
    
    return label_mask.astype(np.int32)  # Keep as integers (not one-hot)

# 🔹 **Function to Load Data Efficiently Using a Generator**
def rugd_generator(split="train"):     
    for root, dirs, files in os.walk(IMG_DIR):
        for file in files:
            if file.endswith('.png'):
                img_path = os.path.join(root, file)
                mask_path = os.path.join(MASK_DIR, os.path.relpath(img_path, IMG_DIR))

                img = load_image(img_path)
                mask = load_mask(mask_path)

                yield img, mask


# 🔹 **Convert Generator to `tf.data.Dataset`**
def get_rugd_dataset(split="train", batch_size=BATCH_SIZE):
    dataset = tf.data.Dataset.from_generator(
        lambda: rugd_generator(split),
        output_signature=(
            tf.TensorSpec(shape=(544, 672, 3), dtype=tf.float32),
            tf.TensorSpec(shape=(544, 672), dtype=tf.int32)
        )
    )

    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)  # Optimize performance
    return dataset

# 🔹 **Create Train, Validation & Test Datasets**
train_files, val_files, test_files = get_data_splits()

train_dataset = get_rugd_dataset(train_files)
val_dataset = get_rugd_dataset(val_files)
test_dataset = get_rugd_dataset(test_files)

print(f"Total images: {len(train_files) + len(val_files) + len(test_files)}")
print(f"Train set: {len(train_files)} images")
print(f"Validation set: {len(val_files)} images")
print(f"Test set: {len(test_files)} images")
# Out:
# Total images: 7436
# Train set: 5948 images
# Validation set: 744 images
# Test set: 744 images

# %%
# Ensure compatibility with TensorFlow 2.x
sm.set_framework("tf.keras")

# Set backbone (EfficientNet or ResNet)
BACKBONE = "efficientnetb3"  # Try 'resnet50' for ResNet backbone

# Load Pretrained U-Net (or PSPNet, FPN)
model = sm.Unet(BACKBONE, 
                encoder_weights="imagenet", 
                classes=25, 
                activation="softmax",
               input_shape=(544, 672, 3)
               )

# Freeze ALL layers initially
for layer in model.layers:
    layer.trainable = False

# Unfreeze only the decoder
for layer in model.layers:
    if "decoder" in layer.name:
        layer.trainable = True  # Fine-tune decoder

# Compile Model
model.compile(optimizer=Adam(learning_rate=0.0001), 
              loss="sparse_categorical_crossentropy", 
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 544, 672, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 272, 336, 40  1080        ['input_1[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 272, 336, 40  160         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 272, 336, 40  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 272, 336, 40  360        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 272, 336, 40  160        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 272, 336, 40  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 40)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 40)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 10)     410         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 40)     440         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 272, 336, 40  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 272, 336, 24  960         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 272, 336, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 272, 336, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 272, 336, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 272, 336, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 272, 336, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 272, 336, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 272, 336, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (FixedDropout)    (None, 272, 336, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 272, 336, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 272, 336, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 272, 336, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 272, 336, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv (DepthwiseConv2  (None, 136, 168, 14  1296       ['block2a_expand_activation[0][0]
#  D)                             4)                               ']
#
#  block2a_bn (BatchNormalization  (None, 136, 168, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 136, 168, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 136, 168, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 136, 168, 32  4608        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 136, 168, 32  128        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 136, 168, 19  6144        ['block2a_project_bn[0][0]']
#                                 2)
#
#  block2b_expand_bn (BatchNormal  (None, 136, 168, 19  768        ['block2b_expand_conv[0][0]']
#  ization)                       2)
#
#  block2b_expand_activation (Act  (None, 136, 168, 19  0          ['block2b_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2b_dwconv (DepthwiseConv2  (None, 136, 168, 19  1728       ['block2b_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2b_bn (BatchNormalization  (None, 136, 168, 19  768        ['block2b_dwconv[0][0]']
#  )                              2)
#
#  block2b_activation (Activation  (None, 136, 168, 19  0          ['block2b_bn[0][0]']
#  )                              2)
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 136, 168, 19  0           ['block2b_activation[0][0]',
#                                 2)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 136, 168, 32  6144        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 136, 168, 32  128        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (FixedDropout)    (None, 136, 168, 32  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 136, 168, 32  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 136, 168, 19  6144        ['block2b_add[0][0]']
#                                 2)
#
#  block2c_expand_bn (BatchNormal  (None, 136, 168, 19  768        ['block2c_expand_conv[0][0]']
#  ization)                       2)
#
#  block2c_expand_activation (Act  (None, 136, 168, 19  0          ['block2c_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2c_dwconv (DepthwiseConv2  (None, 136, 168, 19  1728       ['block2c_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2c_bn (BatchNormalization  (None, 136, 168, 19  768        ['block2c_dwconv[0][0]']
#  )                              2)
#
#  block2c_activation (Activation  (None, 136, 168, 19  0          ['block2c_bn[0][0]']
#  )                              2)
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 136, 168, 19  0           ['block2c_activation[0][0]',
#                                 2)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 136, 168, 32  6144        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 136, 168, 32  128        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (FixedDropout)    (None, 136, 168, 32  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 136, 168, 32  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 136, 168, 19  6144        ['block2c_add[0][0]']
#                                 2)
#
#  block3a_expand_bn (BatchNormal  (None, 136, 168, 19  768        ['block3a_expand_conv[0][0]']
#  ization)                       2)
#
#  block3a_expand_activation (Act  (None, 136, 168, 19  0          ['block3a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block3a_dwconv (DepthwiseConv2  (None, 68, 84, 192)  4800       ['block3a_expand_activation[0][0]
#  D)                                                              ']
#
#  block3a_bn (BatchNormalization  (None, 68, 84, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 68, 84, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 68, 84, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 68, 84, 48)   9216        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 68, 84, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 68, 84, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 68, 84, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 68, 84, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 68, 84, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 68, 84, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 68, 84, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 68, 84, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 68, 84, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 68, 84, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (FixedDropout)    (None, 68, 84, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 68, 84, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 68, 84, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 68, 84, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 68, 84, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 68, 84, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 68, 84, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 68, 84, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 68, 84, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 68, 84, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 68, 84, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (FixedDropout)    (None, 68, 84, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 68, 84, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 68, 84, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 68, 84, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 68, 84, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv (DepthwiseConv2  (None, 34, 42, 288)  2592       ['block4a_expand_activation[0][0]
#  D)                                                              ']
#
#  block4a_bn (BatchNormalization  (None, 34, 42, 288)  1152       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 34, 42, 288)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 34, 42, 288)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 34, 42, 96)   27648       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 34, 42, 96)  384         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 34, 42, 576)  55296       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 34, 42, 576)  2304       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 34, 42, 576)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 34, 42, 576)  5184       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 34, 42, 576)  2304       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 34, 42, 576)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 576)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 34, 42, 576)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 34, 42, 96)   55296       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 34, 42, 96)  384         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (FixedDropout)    (None, 34, 42, 96)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 34, 42, 96)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 34, 42, 576)  55296       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 34, 42, 576)  2304       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 34, 42, 576)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 34, 42, 576)  5184       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 34, 42, 576)  2304       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 34, 42, 576)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 576)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 34, 42, 576)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 34, 42, 96)   55296       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 34, 42, 96)  384         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (FixedDropout)    (None, 34, 42, 96)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 34, 42, 96)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 34, 42, 576)  55296       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 34, 42, 576)  2304       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 34, 42, 576)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 34, 42, 576)  5184       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 34, 42, 576)  2304       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 34, 42, 576)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 576)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 34, 42, 576)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 34, 42, 96)   55296       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 34, 42, 96)  384         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (FixedDropout)    (None, 34, 42, 96)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 34, 42, 96)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 34, 42, 576)  55296       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 34, 42, 576)  2304       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 34, 42, 576)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv (DepthwiseConv2  (None, 34, 42, 576)  5184       ['block4e_expand_activation[0][0]
#  D)                                                              ']
#
#  block4e_bn (BatchNormalization  (None, 34, 42, 576)  2304       ['block4e_dwconv[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 34, 42, 576)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 576)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4e_se_reduce[0][0]']
# ...
#  block7b_se_squeeze (GlobalAver  (None, 2304)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 17, 21, 2304  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 17, 21, 384)  884736      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 17, 21, 384)  1536       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (FixedDropout)    (None, 17, 21, 384)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 17, 21, 384)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 17, 21, 1536  589824      ['block7b_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 17, 21, 1536  6144        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 17, 21, 1536  0           ['top_bn[0][0]']
#                                 )
#
#  decoder_stage0_upsampling (UpS  (None, 34, 42, 1536  0          ['top_activation[0][0]']
#  ampling2D)                     )
#
#  decoder_stage0_concat (Concate  (None, 34, 42, 2352  0          ['decoder_stage0_upsampling[0][0]
#  nate)                          )                                ',
#                                                                   'block6a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage0a_conv (Conv2D)  (None, 34, 42, 256)  5419008     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 34, 42, 256)  1024       ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 34, 42, 256)  0          ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 34, 42, 256)  589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 34, 42, 256)  1024       ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 34, 42, 256)  0          ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 68, 84, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 68, 84, 544)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage1a_conv (Conv2D)  (None, 68, 84, 128)  626688      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 68, 84, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 68, 84, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 68, 84, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 68, 84, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 68, 84, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 136, 168, 12  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     8)
#
#  decoder_stage2_concat (Concate  (None, 136, 168, 32  0          ['decoder_stage2_upsampling[0][0]
#  nate)                          0)                               ',
#                                                                   'block3a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage2a_conv (Conv2D)  (None, 136, 168, 64  184320      ['decoder_stage2_concat[0][0]']
#                                 )
#
#  decoder_stage2a_bn (BatchNorma  (None, 136, 168, 64  256        ['decoder_stage2a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage2a_relu (Activati  (None, 136, 168, 64  0          ['decoder_stage2a_bn[0][0]']
#  on)                            )
#
#  decoder_stage2b_conv (Conv2D)  (None, 136, 168, 64  36864       ['decoder_stage2a_relu[0][0]']
#                                 )
#
#  decoder_stage2b_bn (BatchNorma  (None, 136, 168, 64  256        ['decoder_stage2b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage2b_relu (Activati  (None, 136, 168, 64  0          ['decoder_stage2b_bn[0][0]']
#  on)                            )
#
#  decoder_stage3_upsampling (UpS  (None, 272, 336, 64  0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage3_concat (Concate  (None, 272, 336, 20  0          ['decoder_stage3_upsampling[0][0]
#  nate)                          8)                               ',
#                                                                   'block2a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage3a_conv (Conv2D)  (None, 272, 336, 32  59904       ['decoder_stage3_concat[0][0]']
#                                 )
#
#  decoder_stage3a_bn (BatchNorma  (None, 272, 336, 32  128        ['decoder_stage3a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3a_relu (Activati  (None, 272, 336, 32  0          ['decoder_stage3a_bn[0][0]']
#  on)                            )
#
#  decoder_stage3b_conv (Conv2D)  (None, 272, 336, 32  9216        ['decoder_stage3a_relu[0][0]']
#                                 )
#
#  decoder_stage3b_bn (BatchNorma  (None, 272, 336, 32  128        ['decoder_stage3b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3b_relu (Activati  (None, 272, 336, 32  0          ['decoder_stage3b_bn[0][0]']
#  on)                            )
#
#  decoder_stage4_upsampling (UpS  (None, 544, 672, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 544, 672, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 544, 672, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 544, 672, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 544, 672, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 544, 672, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 544, 672, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 544, 672, 25  3625        ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  softmax (Activation)           (None, 544, 672, 25  0           ['final_conv[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 17,871,313
# Trainable params: 7,082,176
# Non-trainable params: 10,789,137
# __________________________________________________________________________________________________

# %%
tf.config.run_functions_eagerly(True)  # Forces eager execution

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=30
)
# Out:
# Epoch 1/30
# 3718/3718 [==============================] - 12622s 3s/step - loss: 2.0396 - accuracy: 0.7244 - val_loss: 2.1416 - val_accuracy: 0.6750
# Epoch 2/30
# 3718/3718 [==============================] - 12610s 3s/step - loss: 1.6511 - accuracy: 0.7666 - val_loss: 1.7191 - val_accuracy: 0.7418
# Epoch 3/30
# 3718/3718 [==============================] - 12600s 3s/step - loss: 1.3720 - accuracy: 0.7870 - val_loss: 1.4931 - val_accuracy: 0.7408
# Epoch 4/30
# 3718/3718 [==============================] - 12565s 3s/step - loss: 1.1771 - accuracy: 0.8016 - val_loss: 1.3215 - val_accuracy: 0.7739
# Epoch 5/30
# 3718/3718 [==============================] - 12524s 3s/step - loss: 1.0439 - accuracy: 0.8122 - val_loss: 1.2593 - val_accuracy: 0.7808
# Epoch 6/30
# 3718/3718 [==============================] - 12566s 3s/step - loss: 0.9430 - accuracy: 0.8191 - val_loss: 1.2264 - val_accuracy: 0.7818
# Epoch 7/30
# 3718/3718 [==============================] - 12631s 3s/step - loss: 0.8658 - accuracy: 0.8300 - val_loss: 1.2691 - val_accuracy: 0.7681
# Epoch 8/30
# 3718/3718 [==============================] - 12613s 3s/step - loss: 0.8052 - accuracy: 0.8384 - val_loss: 1.2841 - val_accuracy: 0.7603
# Epoch 9/30
# 3718/3718 [==============================] - 12660s 3s/step - loss: 0.7488 - accuracy: 0.8459 - val_loss: 1.1937 - val_accuracy: 0.7911
# Epoch 10/30
# 2369/3718 [==================>...........] - ETA: 40:46 - loss: 0.8138 - accuracy: 0.8272
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 history = model.fit(
#       2     train_dataset,
#       3     validation_data=val_dataset,
#       4     epochs=30
#       5 )
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\training.py:1160, in Model.make_train_function.<locals>.train_function(iterator)
#    1158 def train_function(iterator):
#    1159     """Runs a training execution with a single step."""
# -> 1160     return step_function(self, iterator)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\training.py:1146, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1142     run_step = tf.function(
#    1143         run_step, jit_compile=True, reduce_retracing=True
#    1144     )
#    1145 data = next(iterator)
# -> 1146 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1147 outputs = reduce_per_replica(
#    1148     outputs, self.distribute_strategy, reduction="first"
#    1149 )
#    1150 return outputs
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1315, in StrategyBase.run(***failed resolving arguments***)
#    1310 with self.scope():
#    1311   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1312   # applied when the caller is also in Eager mode.
#    1313   fn = autograph.tf_convert(
#    1314       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1315   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2891, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2889   kwargs = {}
#    2890 with self._container_strategy().scope():
# -> 2891   return self._call_for_each_replica(fn, args, kwargs)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3692, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3690 def _call_for_each_replica(self, fn, args, kwargs):
#    3691   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3692     return fn(*args, **kwargs)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\training.py:1135, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1134 def run_step(data):
# -> 1135     outputs = model.train_step(data)
#    1136     # Ensure counter is updated only if `train_step` succeeds.
#    1137     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\training.py:993, in Model.train_step(self, data)
#     991 # Run forward pass.
#     992 with tf.GradientTape() as tape:
# --> 993     y_pred = self(x, training=True)
#     994     loss = self.compute_loss(x, y, y_pred, sample_weight)
#     995 self._validate_target_and_loss(y, loss)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\training.py:557, in Model.__call__(self, *args, **kwargs)
#     553         super().__call__(inputs, *copied_args, **copied_kwargs)
#     555     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 557 return super().__call__(*args, **kwargs)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\functional.py:510, in Functional.call(self, inputs, training, mask)
#     491 @doc_controls.do_not_doc_inheritable
#     492 def call(self, inputs, training=None, mask=None):
#     493     """Calls the model on new inputs.
#     494
#     495     In this case `call` just reapplies
#    (...)
#     508         a list of tensors if there are more than one outputs.
#     509     """
# --> 510     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\functional.py:667, in Functional._run_internal_graph(self, inputs, training, mask)
#     664     continue  # Node is not computable, try skipping.
#     666 args, kwargs = node.map_arguments(tensor_dict)
# --> 667 outputs = node.layer(*args, **kwargs)
#     669 # Update tensor_dict.
#     670 for x_id, y in zip(
#     671     node.flat_output_ids, tf.nest.flatten(outputs)
#     672 ):
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File C:\Programs\ML\envs\tensorflow2\lib\site-packages\keras\layers\normalization\batch_normalization.py:850, in BatchNormalizationBase.call(self, inputs, training)
#     847         return outputs
#     849 if self.fused:
# --> 850     outputs = self._fused_batch_norm(inputs, training=training)
#     851     if self.virtual_batch_size is not None:
#     852         # Currently never reaches here since fused_batch_norm does not
#     853         # support virtual batching
#     854         outputs = undo_virtual_batching(outputs)
#
# KeyboardInterrupt:

# %%
model.save("model_name.keras")

# %%
# Evaluate on Validation Set
val_loss, val_acc = model.evaluate(val_dataset)
print(f"Validation Accuracy: {val_acc:.4f}")

# Test on a Sample Image
for test_img, test_mask in test_dataset.take(1):  # Take first test batch
    pred_mask = model.predict(test_img)
    pred_mask = np.argmax(pred_mask, axis=-1)  # Convert from one-hot to class indices
    break  # Only process one batch

# Display Results
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1); plt.imshow(test_img[0]); plt.title("Input Image")
plt.subplot(1, 3, 2); plt.imshow(test_mask[0]); plt.title("Ground Truth")
plt.subplot(1, 3, 3); plt.imshow(pred_mask[0]); plt.title("Predicted Mask")
plt.show()
# Out:
#    2846/Unknown - 4732s 2s/step - loss: 1.1117 - accuracy: 0.7686
